# %%
from scipy import stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import time

# %%
df = pd.read_excel("C:/Users/user/Downloads/미니프로젝트-쇼핑몰 실습데이터.xlsx")

# %%
list1 = []
for i in range(218601):
    x = df['주문일자'][i]
    list1 += [x.date()]

# %%
list2 = []
for i in range(218601):
    x = list1[i]
    y = x.month
    list2 += [y]

# %%
df['주문연월'] = list2

# %%
df
# Out:
#                    주문번호    업체명                                  상품명    제조사  \
# 0       191213170236874     지니            eHBM셀파수학교실 비닐봉투-1세트 100장입     HB
# 1       191216100347429     지니            eHBM셀파수학교실 비닐봉투-1세트 100장입     HB
# 2       191216100347429     지니             eHBM셀파수학교실 삼색볼펜-1세트 50개입     HB
# 3       191216173241622     지니          eHBM셀파수학교실 회원용 리플렛-1세트 50권입     HB
# 4       191216173241622     지니              eHBM셀파수학교실-학습계통도(중등 5종)     HB
# ...                 ...    ...                                  ...    ...
# 218596  221108104041264  에이스디포               [스마트 HBE*초도] 입체 액자형 현판  에이스디포
# 218597  221108104041264  에이스디포                  [스마트 HBE*초도] 아크릴 사인     HB
# 218598  221108104536307  에이스디포                     [스마트 HBM] 아크릴 사인     HB
# 218599  221108104735216   다우기술                [스타벅스] 아이스 카페 아메리카노 T   스타벅스
# 218600  221108105148171   다우기술  [특별한 크리스마스] 2차-신세계 상품권 모바일 교환권-1만원권    신세계
#
#         주문수량    판매금액   결제방법                주문일자  처리상태 초도상품 제작문구 내역 할부기간  주문연월
# 0          1    5000   신용카드 2019-12-13 17:03:37  구매확정    N     NaN  NaN    12
# 1          1    5000   신용카드 2019-12-16 10:04:50  구매확정    N     NaN  NaN    12
# 2          3   67500   신용카드 2019-12-16 10:04:50  구매확정    N     NaN  NaN    12
# 3          2   30000   신용카드 2019-12-16 17:33:43  구매확정    N     NaN  NaN    12
# 4          1     750   신용카드 2019-12-16 17:33:43  구매확정    N     NaN  NaN    12
# ...      ...     ...    ...                 ...   ...  ...     ...  ...   ...
# 218596     1   35000   웰컴마일 2022-11-08 10:38:21  결제완료    Y     NaN  NaN    11
# 218597     1   26900   웰컴마일 2022-11-08 10:38:21  결제완료    Y     NaN  NaN    11
# 218598     1   26900  신 + 포 2022-11-08 10:43:15  배송준비    N     NaN  NaN    11
# 218599     1    4050    포인트 2022-11-08 10:45:14  배송완료    N     NaN  NaN    11
# 218600    17  161500   신용카드 2022-11-08 10:49:28  배송완료    N     NaN  NaN    11
#
# [218601 rows x 13 columns]

# %%
df2 = df.copy()

# %%
df2 = df2[df2['처리상태'] == '구매확정']

# %%
df2
# Out:
#                    주문번호   업체명                          상품명   제조사  주문수량   판매금액  \
# 0       191213170236874    지니    eHBM셀파수학교실 비닐봉투-1세트 100장입    HB     1   5000
# 1       191216100347429    지니    eHBM셀파수학교실 비닐봉투-1세트 100장입    HB     1   5000
# 2       191216100347429    지니     eHBM셀파수학교실 삼색볼펜-1세트 50개입    HB     3  67500
# 3       191216173241622    지니  eHBM셀파수학교실 회원용 리플렛-1세트 50권입    HB     2  30000
# 4       191216173241622    지니      eHBM셀파수학교실-학습계통도(중등 5종)    HB     1    750
# ...                 ...   ...                          ...   ...   ...    ...
# 217852  221106231538662  다우기술            [올리브영] 기프트카드 1만원권  올리브영     2  19200
# 217914  221107074704768  다우기술    [따뜻달달특가] 빽다방-빽′s카페라떼(HOT)   빽다방     1   2550
# 217927  221107081217959  다우기술          [GS25] 모바일 상품권 2천원권  GS25     1   1800
# 217938  221107083418760  다우기술            [이디야] 연유 카페라떼 HOT   이디야     1   3400
# 217940  221107090224476  다우기술      [따뜻달달특가] 빽다방-앗메리카노(HOT)   빽다방     1   1300
#
#          결제방법                주문일자  처리상태 초도상품 제작문구 내역 할부기간  주문연월
# 0        신용카드 2019-12-13 17:03:37  구매확정    N     NaN  NaN    12
# 1        신용카드 2019-12-16 10:04:50  구매확정    N     NaN  NaN    12
# 2        신용카드 2019-12-16 10:04:50  구매확정    N     NaN  NaN    12
# 3        신용카드 2019-12-16 17:33:43  구매확정    N     NaN  NaN    12
# 4        신용카드 2019-12-16 17:33:43  구매확정    N     NaN  NaN    12
# ...       ...                 ...   ...  ...     ...  ...   ...
# 217852   신용카드 2022-11-06 23:13:17  구매확정    N     NaN  NaN    11
# 217914   신용카드 2022-11-07 07:44:43  구매확정    N     NaN  NaN    11
# 217927  신 + 포 2022-11-07 08:09:57  구매확정    N     NaN  NaN    11
# 217938    포인트 2022-11-07 08:31:57  구매확정    N     NaN  NaN    11
# 217940  신 + 포 2022-11-07 09:00:03  구매확정    N     NaN  NaN    11
#
# [159291 rows x 13 columns]

# %%
plt.bar(df2['주문연월'], df2['판매금액'])
# Out:
# <BarContainer object of 159291 artists>
